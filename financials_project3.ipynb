# %%
import pandas as pd
import os

# %%
financial_df = pd.read_csv('Raw_Data/financials.csv')
sandp_df = pd.read_csv('Raw_Data/sp500_companies.csv')

# %%
financials_complete_df = pd.merge(financial_df, sandp_df, how="left", on=["Symbol", "Symbol"])

# %%
financials_complete_df.head()
# Out:
#   Symbol                 Name                Sector_x   Price  Price/Earnings  \
# 0    MMM           3M Company             Industrials  222.89           24.31
# 1    AOS      A.O. Smith Corp             Industrials   60.24           27.76
# 2    ABT  Abbott Laboratories             Health Care   56.27           22.51
# 3   ABBV          AbbVie Inc.             Health Care  108.48           19.41
# 4    ACN        Accenture plc  Information Technology  150.51           25.47
#
#    Dividend Yield  Earnings/Share  52 Week Low  52 Week High    Market Cap  \
# 0        2.332862            7.92       259.77       175.490  1.387211e+11
# 1        1.147959            1.70        68.39        48.925  1.078342e+10
# 2        1.908982            0.26        64.60        42.280  1.021210e+11
# 3        2.499560            3.29       125.86        60.050  1.813863e+11
# 4        1.714470            5.44       162.60       114.820  9.876586e+10
#
# ...

# %%
for col in financials_complete_df.columns:
    print(col)
# Out:
# Symbol
# Name
# Sector_x
# Price
# Price/Earnings
# Dividend Yield
# Earnings/Share
# 52 Week Low
# 52 Week High
# Market Cap
# EBITDA
# Price/Sales
# Price/Book
# SEC Filings
# Exchange
# Shortname
# Longname
# Sector_y
# Industry
# Currentprice
# Marketcap
# Ebitda
# Revenuegrowth
# City
# State
# Country
# Fulltimeemployees
# Longbusinesssummary
# Weight

# %%
financials_complete_df.drop(columns=['Shortname', 'Longname', 'Sector_y', 'Market Cap', 'EBITDA', 'Price/Sales', 'Price/Book', 'SEC Filings'])
# Out:
#     Symbol                    Name                Sector_x   Price  \
# 0      MMM              3M Company             Industrials  222.89
# 1      AOS         A.O. Smith Corp             Industrials   60.24
# 2      ABT     Abbott Laboratories             Health Care   56.27
# 3     ABBV             AbbVie Inc.             Health Care  108.48
# 4      ACN           Accenture plc  Information Technology  150.51
# ..     ...                     ...                     ...     ...
# 500    XYL              Xylem Inc.             Industrials   70.24
# 501    YUM         Yum! Brands Inc  Consumer Discretionary   76.30
# 502    ZBH  Zimmer Biomet Holdings             Health Care  115.53
# 503   ZION           Zions Bancorp              Financials   50.71
# 504    ZTS                  Zoetis             Health Care   71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# ...

# %%
final_financials = financials_complete_df.rename(columns={"Currentprice": "Current Price: 7-11-22", "52 Week Low": "2020 52 Week Low", "52 Week High": "2020 52 Week High"})

# %%
final_financials.head()
# Out:
#   Symbol                 Name                Sector_x   Price  Price/Earnings  \
# 0    MMM           3M Company             Industrials  222.89           24.31
# 1    AOS      A.O. Smith Corp             Industrials   60.24           27.76
# 2    ABT  Abbott Laboratories             Health Care   56.27           22.51
# 3   ABBV          AbbVie Inc.             Health Care  108.48           19.41
# 4    ACN        Accenture plc  Information Technology  150.51           25.47
#
#    Dividend Yield  Earnings/Share  2020 52 Week Low  2020 52 Week High  \
# 0        2.332862            7.92            259.77            175.490
# 1        1.147959            1.70             68.39             48.925
# 2        1.908982            0.26             64.60             42.280
# 3        2.499560            3.29            125.86             60.050
# 4        1.714470            5.44            162.60            114.820
#
# ...

# %%
final_financials.set_index('Symbol')
# Out:
#                           Name                Sector_x   Price  \
# Symbol
# MMM                 3M Company             Industrials  222.89
# AOS            A.O. Smith Corp             Industrials   60.24
# ABT        Abbott Laboratories             Health Care   56.27
# ABBV               AbbVie Inc.             Health Care  108.48
# ACN              Accenture plc  Information Technology  150.51
# ...                        ...                     ...     ...
# XYL                 Xylem Inc.             Industrials   70.24
# YUM            Yum! Brands Inc  Consumer Discretionary   76.30
# ZBH     Zimmer Biomet Holdings             Health Care  115.53
# ZION             Zions Bancorp              Financials   50.71
# ZTS                     Zoetis             Health Care   71.51
#
#         Price/Earnings  Dividend Yield  Earnings/Share  2020 52 Week Low  \
# Symbol
# MMM              24.31        2.332862            7.92            259.77
# ...
